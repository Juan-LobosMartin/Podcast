# %%
# Modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load DataFrames
Podcast_Train_df = pd.read_csv('Data/train.csv')
Podcast_Test_df = pd.read_csv('Data/test.csv')

# %%
Podcast_Train_df
# Out:
#             id      Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0            0   Mystery Matters    Episode 98                     NaN
# 1            1     Joke Junction    Episode 26                  119.80
# 2            2    Study Sessions    Episode 16                   73.90
# 3            3    Digital Digest    Episode 45                   67.17
# 4            4       Mind & Body    Episode 86                  110.51
# ...        ...               ...           ...                     ...
# 749995  749995      Learning Lab    Episode 25                   75.66
# 749996  749996   Business Briefs    Episode 21                   75.75
# 749997  749997  Lifestyle Lounge    Episode 51                   30.98
# 749998  749998       Style Guide    Episode 47                  108.98
# 749999  749999    Sports Central    Episode 99                   24.10
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
len(Podcast_Train_df['Podcast_Name'].value_counts())
# Out:
# 48

# %%
len(Podcast_Test_df['Podcast_Name'].unique())
# Out:
# 48

# %%
Podcast_Train_df['Podcast_Name'].unique()
# Out:
# array(['Mystery Matters', 'Joke Junction', 'Study Sessions',
#        'Digital Digest', 'Mind & Body', 'Fitness First', 'Criminal Minds',
#        'News Roundup', 'Daily Digest', 'Music Matters', 'Sports Central',
#        'Melody Mix', 'Game Day', 'Gadget Geek', 'Global News',
#        'Tech Talks', 'Sport Spot', 'Funny Folks', 'Sports Weekly',
#        'Business Briefs', 'Tech Trends', 'Innovators', 'Health Hour',
#        'Comedy Corner', 'Sound Waves', 'Brain Boost', "Athlete's Arena",
#        'Wellness Wave', 'Style Guide', 'World Watch', 'Humor Hub',
#        'Money Matters', 'Healthy Living', 'Home & Living',
#        'Educational Nuggets', 'Market Masters', 'Learning Lab',
#        'Lifestyle Lounge', 'Crime Chronicles', 'Detective Diaries',
#        'Life Lessons', 'Current Affairs', 'Finance Focus', 'Laugh Line',
#        'True Crime Stories', 'Business Insights', 'Fashion Forward',
#        'Tune Time'], dtype=object)

# %%
len(Podcast_Train_df['Genre'].value_counts())
# Out:
# 10

# %%
len(Podcast_Test_df['Genre'].value_counts())
# Out:
# 10

# %%
Podcast_Train_df['Publication_Day'].unique()
# Out:
# array(['Thursday', 'Saturday', 'Tuesday', 'Monday', 'Sunday', 'Wednesday',
#        'Friday'], dtype=object)

# %%
len(Podcast_Train_df['Publication_Day'].unique())
# Out:
# 7

# %%
Podcast_Train_df['Publication_Time'].unique()
# Out:
# array(['Night', 'Afternoon', 'Evening', 'Morning'], dtype=object)

# %%
len(Podcast_Train_df['Publication_Time'].unique())
# Out:
# 4

# %%
podcast_data = pd.DataFrame(columns=['Program','# progam','day','# week day','Time','# on that hour','mean','std'])

# %%
podcast_data
# Out:
# Empty DataFrame
# Columns: [Program, # progam, day, # week day, Time, # on that hour, mean, std]
# Index: []

# %%
# Pod_My_Ma[(Pod_My_Ma['Publication_Day']== 'Saturday') & (Pod_My_Ma['Publication_Time']== 'Morning')]['Episode_Length_minutes'].median()

# %%
n=0
for podcast in Podcast_Test_df['Podcast_Name'].unique():
    podname_df = Podcast_Train_df[Podcast_Train_df['Podcast_Name'] == podcast]
    feature = podcast
    program_num = len(podname_df)
    
    for day in podname_df['Publication_Day'].unique():
        pub_day_df = podname_df[podname_df['Publication_Day'] == day ]
        pod_day = day
        pod_day_num = len(pub_day_df)

        for hour in pub_day_df['Publication_Time'].unique():
            pub_hour_df = pub_day_df[pub_day_df['Publication_Time'] == hour ]
            time = hour
            time_num = len(pub_hour_df)
            mean = pub_hour_df['Episode_Length_minutes'].mean()
            std = pub_hour_df['Episode_Length_minutes'].std()
            podcast_data.loc[n] = [feature, program_num, pod_day, pod_day_num, time, time_num, mean, std]
            n = n +1
        n= n +4
    n=n +7

# %%
podcast_data
# Out:
#                   Program  # progam       day  # week day       Time  \
# 0     Educational Nuggets     12245    Monday        1753    Morning
# 1     Educational Nuggets     12245    Monday        1753    Evening
# 2     Educational Nuggets     12245    Monday        1753  Afternoon
# 3     Educational Nuggets     12245    Monday        1753      Night
# 8     Educational Nuggets     12245    Sunday        1870      Night
# ...                   ...       ...       ...         ...        ...
# 3004         News Roundup      9169    Monday        1393    Morning
# 3009         News Roundup      9169  Saturday        1260      Night
# 3010         News Roundup      9169  Saturday        1260    Morning
# 3011         News Roundup      9169  Saturday        1260    Evening
# 3012         News Roundup      9169  Saturday        1260  Afternoon
#
#       # on that hour       mean        std
# 0                400  63.721253  32.639350
# 1                509  63.950889  32.486647
# ...

# %%
podcast_data.to_csv('Data/Podcast_data.csv', index=True)

# %%
podcast_data_order = pd.DataFrame(columns=['Program','# progam','day','# week day','Time','# in hour','mean','std'])

# %%
podcast_data_order
# Out:
# Empty DataFrame
# Columns: [Program, # progam, day, # week day, Time, # in hour, mean, std]
# Index: []

# %%
n=0
for podcast in Podcast_Test_df['Podcast_Name'].unique():
    podname_df = Podcast_Train_df[Podcast_Train_df['Podcast_Name'] == podcast]
    feature = podcast
    program_num = len(podname_df)
    
    for day in ['Sunday' ,'Monday' ,'Tuesday' ,'Wednesday','Thursday','Friday', 'Saturday']:
        try:
            pub_day_df = podname_df[podname_df['Publication_Day'] == day ]
            pod_day = day
            pod_day_num = len(pub_day_df)
        except:
            pub_day_df = podname_df
            pod_day = day
            pod_day_num = np.nan

        for hour in ['Night','Morning', 'Afternoon', 'Evening']:
            try:
                pub_hour_df = pub_day_df[pub_day_df['Publication_Time'] == hour ]
                time = hour
                time_num = len(pub_hour_df)
                mean = pub_hour_df['Episode_Length_minutes'].mean()
                std = pub_hour_df['Episode_Length_minutes'].std()
            except:
                pub_hour_df = pub_day_df
                time = hour
                time_num = np.nan
                mean = np.nan
                std = np.nan
                
            podcast_data_order.loc[n] = [feature, program_num, pod_day, pod_day_num, time, time_num, mean, std]
            n = n +1
        n= n +4
    n=n +7

# %%
podcast_data_order
# Out:
#                   Program  # progam       day  # week day       Time  \
# 0     Educational Nuggets     12245    Sunday        1870      Night
# 1     Educational Nuggets     12245    Sunday        1870    Morning
# 2     Educational Nuggets     12245    Sunday        1870  Afternoon
# 3     Educational Nuggets     12245    Sunday        1870    Evening
# 8     Educational Nuggets     12245    Monday        1753      Night
# ...                   ...       ...       ...         ...        ...
# 3004         News Roundup      9169    Friday        1310    Evening
# 3009         News Roundup      9169  Saturday        1260      Night
# 3010         News Roundup      9169  Saturday        1260    Morning
# 3011         News Roundup      9169  Saturday        1260  Afternoon
# 3012         News Roundup      9169  Saturday        1260    Evening
#
#       # in hour       mean        std
# 0           485  66.501642  31.548580
# 1           411  63.443003  33.950159
# ...

# %%
podcast_data_order.to_csv('Data/Podcast_data_order.csv', index=True)

# %%
podcast_data_order.describe()
# Out:
#            # progam   # week day    # in hour         mean          std
# count   1344.000000  1344.000000  1344.000000  1344.000000  1344.000000
# mean   15625.000000  2232.142857   558.035714    64.487832    32.907744
# std     2798.750697   431.806178   116.500130     2.664202     1.067797
# min     9169.000000  1251.000000   274.000000    52.254230    28.651971
# 25%    13388.250000  1888.750000   471.000000    62.891472    32.179471
# 50%    15500.500000  2205.000000   545.000000    64.518748    32.869592
# 75%    17393.500000  2533.500000   637.000000    66.253130    33.613847
# max    22847.000000  3521.000000   933.000000    72.439976    37.132306

# %%
podcast_Test_order = pd.DataFrame(columns=['Program','# progam','day','# week day','Time','# in hour','mean','std'])

# %%
podcast_Test_order
# Out:
# Empty DataFrame
# Columns: [Program, # progam, day, # week day, Time, # in hour, mean, std]
# Index: []

# %%
n=0
for podcast in Podcast_Test_df['Podcast_Name'].unique():
    podname_df = Podcast_Test_df[Podcast_Test_df['Podcast_Name'] == podcast]
    feature = podcast
    program_num = len(podname_df)
    
    for day in ['Sunday' ,'Monday' ,'Tuesday' ,'Wednesday','Thursday','Friday', 'Saturday']:
        try:
            pub_day_df = podname_df[podname_df['Publication_Day'] == day ]
            pod_day = day
            pod_day_num = len(pub_day_df)
        except:
            pub_day_df = podname_df
            pod_day = day
            pod_day_num = np.nan

        for hour in ['Night','Morning', 'Afternoon', 'Evening']:
            try:
                pub_hour_df = pub_day_df[pub_day_df['Publication_Time'] == hour ]
                time = hour
                time_num = len(pub_hour_df)
                mean = pub_hour_df['Episode_Length_minutes'].mean()
                std = pub_hour_df['Episode_Length_minutes'].std()
            except:
                pub_hour_df = pub_day_df
                time = hour
                time_num = np.nan
                mean = np.nan
                std = np.nan
                
            podcast_Test_order.loc[n] = [feature, program_num, pod_day, pod_day_num, time, time_num, mean, std]
            n = n +1
        n= n +4
    n=n +7

# %%
podcast_Test_order.describe()
# Out:
#           # progam   # week day    # in hour           mean           std
# count  1344.000000  1344.000000  1344.000000    1344.000000  1.344000e+03
# mean   5208.333333   744.047619   186.011905     429.549597  4.650056e+03
# std     921.740515   144.738542    40.152018   13380.465482  1.692510e+05
# min    3138.000000   421.000000    79.000000      50.031061  2.844882e+01
# 25%    4475.750000   636.000000   155.000000      62.248569  3.190707e+01
# 50%    5142.500000   725.000000   182.000000      64.584068  3.288597e+01
# 75%    5814.000000   854.750000   212.250000      66.850036  3.385007e+01
# max    7553.000000  1145.000000   324.000000  490600.515188  6.204879e+06

# %%
podcast_Test_order
# Out:
#                   Program  # progam       day  # week day       Time  \
# 0     Educational Nuggets      3963    Sunday         630      Night
# 1     Educational Nuggets      3963    Sunday         630    Morning
# 2     Educational Nuggets      3963    Sunday         630  Afternoon
# 3     Educational Nuggets      3963    Sunday         630    Evening
# 8     Educational Nuggets      3963    Monday         535      Night
# ...                   ...       ...       ...         ...        ...
# 3004         News Roundup      3138    Friday         449    Evening
# 3009         News Roundup      3138  Saturday         421      Night
# 3010         News Roundup      3138  Saturday         421    Morning
# 3011         News Roundup      3138  Saturday         421  Afternoon
# 3012         News Roundup      3138  Saturday         421    Evening
#
#       # in hour       mean        std
# 0           149  65.795371  31.953644
# 1           149  67.633185  34.922508
# ...

# %%
Podcast_Test_df.describe()
# Out:
#                   id  Episode_Length_minutes  Host_Popularity_percentage  \
# count  250000.000000            2.212640e+05               250000.000000
# mean   874999.500000            4.192987e+02                   59.716491
# std     72168.927986            1.668545e+05                   22.880028
# min    750000.000000            2.470000e+00                    2.490000
# 25%    812499.750000            3.578000e+01                   39.250000
# 50%    874999.500000            6.397000e+01                   59.900000
# 75%    937499.250000            9.415000e+01                   79.390000
# max    999999.000000            7.848626e+07                  117.760000
#
#        Guest_Popularity_percentage  Number_of_Ads
# count                201168.000000  250000.000000
# mean                     52.192796       1.355852
# std                      28.445034       4.274399
# min                       0.000000       0.000000
# 25%                      28.320000       0.000000
# ...

# %%
Podcast_Train_df.describe()
# Out:
#                   id  Episode_Length_minutes  Host_Popularity_percentage  \
# count  750000.000000           662907.000000               750000.000000
# mean   374999.500000               64.504738                   59.859901
# std    216506.495284               32.969603                   22.873098
# min         0.000000                0.000000                    1.300000
# 25%    187499.750000               35.730000                   39.410000
# 50%    374999.500000               63.840000                   60.050000
# 75%    562499.250000               94.070000                   79.530000
# max    749999.000000              325.240000                  119.460000
#
#        Guest_Popularity_percentage  Number_of_Ads  Listening_Time_minutes
# count                603970.000000  749999.000000           750000.000000
# mean                     52.236449       1.348855               45.437406
# std                      28.451241       1.151130               27.138306
# ...

# %%
# how many programs of more than 120 minutes
Podcast_Train_df[Podcast_Train_df['Episode_Length_minutes']>120]
# Out:
#             id      Podcast_Name Episode_Title  Episode_Length_minutes  \
# 74270    74270       Tech Trends    Episode 31                  120.64
# 87034    87034        Tech Talks    Episode 31                  120.32
# 101637  101637     Home & Living    Episode 16                  325.24
# 168115  168115     Wellness Wave    Episode 78                  120.64
# 473895  473895   Athlete's Arena    Episode 15                  120.06
# 516498  516498   Fashion Forward    Episode 81                  120.37
# 552181  552181   Athlete's Arena    Episode 15                  120.73
# 598106  598106  Crime Chronicles    Episode 53                  120.93
# 688205  688205        Melody Mix    Episode 70                  120.37
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# 74270   Technology                       49.78        Saturday
# 87034   Technology                       78.39        Thursday
# 101637   Lifestyle                       50.69         Tuesday
# ...

# %%
Podcast_Test_df[Podcast_Test_df['Episode_Length_minutes']>120]
# Out:
#             id       Podcast_Name Episode_Title  Episode_Length_minutes  \
# 54434   804434    Current Affairs    Episode 36                 7575.00
# 56597   806597     Market Masters    Episode 23             78486264.00
# 72201   822201  Detective Diaries    Episode 81                  120.37
# 180050  930050         Tech Talks    Episode 23                  120.73
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# 54434         News                       89.54        Saturday
# 56597     Business                       55.45          Monday
# 72201   True Crime                       79.40        Thursday
# 180050  Technology                       50.27          Friday
#
#        Publication_Time  Guest_Popularity_percentage  Number_of_Ads  \
# 54434             Night                          NaN            2.0
# 56597           Evening                        48.50            0.0
# 72201         Afternoon                          NaN            0.0
# ...

# %%
# How many programs Host_Popularity_percentage more than 99
Podcast_Train_df[Podcast_Train_df['Host_Popularity_percentage']>100]
# Out:
#             id        Podcast_Name Episode_Title  Episode_Length_minutes  \
# 23925    23925       Fitness First    Episode 79                   93.17
# 79078    79078     Current Affairs    Episode 17                  107.24
# 111850  111850          Melody Mix    Episode 43                  115.31
# 113304  113304       Wellness Wave    Episode 67                   35.35
# 123611  123611       Finance Focus    Episode 86                   34.18
# 132903  132903     Fashion Forward    Episode 50                   64.04
# 170608  170608     Fashion Forward    Episode 55                   64.03
# 176422  176422    Lifestyle Lounge    Episode 70                  116.43
# 183757  183757       Fitness First    Episode 79                   93.17
# 187862  187862  True Crime Stories    Episode 86                   34.17
# 206015  206015          Innovators    Episode 16                   73.15
# 222880  222880         Tech Trends    Episode 68                  105.76
# ...

# %%
Podcast_Test_df[Podcast_Test_df['Host_Popularity_percentage']>100]
# Out:
#             id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 59446   809446    Detective Diaries    Episode 47                   71.98
# 70250   820250     Lifestyle Lounge    Episode 41                  105.71
# 88169   838169          World Watch    Episode 67                   39.72
# 90886   840886        Fitness First    Episode 79                   93.17
# 106857  856857    Detective Diaries    Episode 10                  112.80
# 108106  858106    Detective Diaries    Episode 71                  105.51
# 124250  874250      Current Affairs    Episode 69                   55.06
# 127620  877620    Detective Diaries    Episode 50                   65.09
# 143693  893693          World Watch    Episode 78                   10.71
# 180528  930528         News Roundup    Episode 64                  103.11
# 183787  933787      Fashion Forward    Episode 50                   64.03
# 186742  936742  Educational Nuggets    Episode 45                  116.60
#
# ...

# %%
# How many programs Guest_Popularity_percentage more than 99.99
Podcast_Train_df[Podcast_Train_df['Guest_Popularity_percentage']>100]
# Out:
#             id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 6770      6770            Tune Time    Episode 85                     NaN
# 32435    32435          World Watch    Episode 44                   10.94
# 86967    86967            Tune Time    Episode 68                   35.62
# 106804  106804            Tune Time    Episode 79                   45.36
# 118315  118315          Style Guide    Episode 32                   80.30
# 149146  149146           Laugh Line    Episode 21                   92.27
# 194629  194629            Tune Time    Episode 85                     NaN
# 202865  202865      Athlete's Arena    Episode 19                    7.30
# 253381  253381           Innovators    Episode 44                     NaN
# 259197  259197  Educational Nuggets    Episode 76                   55.02
# 291133  291133      Athlete's Arena    Episode 85                  115.16
# 301452  301452     Lifestyle Lounge    Episode 15                     NaN
# ...

# %%
Podcast_Test_df[Podcast_Test_df['Guest_Popularity_percentage']>100]
# Out:
#             id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 78898   828898    Detective Diaries    Episode 61                   24.29
# 121878  871878            Humor Hub    Episode 28                   99.32
# 192155  942155            Tune Time    Episode 48                  102.89
# 199455  949455  Educational Nuggets    Episode 76                   55.82
# 211582  961582            Humor Hub    Episode 28                   80.33
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# 78898   True Crime                       80.60          Friday
# 121878      Comedy                       81.54          Monday
# 192155       Music                       90.38          Monday
# 199455   Education                       69.43         Tuesday
# 211582      Comedy                       71.52          Monday
#
#        Publication_Time  Guest_Popularity_percentage  Number_of_Ads  \
# 78898             Night                       116.32            1.0
# ...

# %%
len(Podcast_Train_df[Podcast_Train_df['Host_Popularity_percentage']>100])
# Out:
# 25

# %%
len(Podcast_Test_df[Podcast_Test_df['Host_Popularity_percentage']>100])
# Out:
# 12

# %%
len(Podcast_Train_df[Podcast_Train_df['Guest_Popularity_percentage']>100])
# Out:
# 19

# %%
len(Podcast_Test_df[Podcast_Test_df['Guest_Popularity_percentage']>100])
# Out:
# 5
